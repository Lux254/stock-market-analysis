# %%
#plot the actual vs the predicted values
plt.figure(figsize=(10,6))
plt.plot(y_test_true, label="Actual Prices")
plt.plot(predicted, label="Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()
